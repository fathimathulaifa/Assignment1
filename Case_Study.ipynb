# %% [markdown]
# <a href="https://colab.research.google.com/github/fathimathulaifa/Assignment1/blob/main/Case_Study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Bank Account Manager**

# %%
# starting balance
balance = 1000

def deposit(balance, amount):
    balance = balance + amount
    print(f"Deposited ₹{amount}. New Balance: ₹{balance}")
    return balance

def withdraw(balance, amount):
    if amount <= balance:
        balance = balance - amount
        print(f"Withdrew ₹{amount}. Remaining Balance: ₹{balance}")
    else:
        print("Insufficient balance! Withdrawal failed.")
    return balance

def check_balance(balance):
    print(f"Current Balance: ₹{balance}")

# %% [markdown]
# **Output**

# %%
balance = deposit(balance, 500)
balance = withdraw(balance, 200)
check_balance(balance)

balance = withdraw(balance, 2000)   # this will fail because no balance
check_balance(balance)
# Out:
# Deposite:rs 500 new balnce: 1800
# Withdrew ₹200. Remaining Balance: ₹1600
# Current Balance: ₹1600
# Insufficient balance! Withdrawal failed.
# Current Balance: ₹1600

# %%
balance = withdraw(balance, 100)   # this will fail because no balance
check_balance(balance)
balance=withdraw(balance,300)
check_balance(balance)
# Out:
# Withdrew ₹100. Remaining Balance: ₹1500
# Current Balance: ₹1500
# Withdrew ₹300. Remaining Balance: ₹1200
# Current Balance: ₹1200

# %% [markdown]
# **Weather Data Analyzer**

# %%
# Weather data for a region
region = "kerala"
temperatures = [45, 42, 31, 29, 54, 36,33]        # temperature in °C
humidity_levels = [75, 45, 78, 75, 85, 91,46]     # humidity in %

# %%
# Determine weather condition
def classify_weather(temp, humidity):
    if temp > 33:
        return "Hot"
    elif humidity > 85:
        return "Possible Rain"
    else:
        return "Normal"

# %%
# Calculate average temperature
def average_temperature(temp_list):
    return sum(temp_list) / len(temp_list)

# %%
# Calculate average humidity
def average_humidity(humidity_list):
    return sum(humidity_list) / len(humidity_list)

# %%
# Analyze day-wise weather
def analyze_daily_weather(temps, humidity):
    print(f"Weather Report for {region}:\n")
    for i in range(len(temps)):
        condition = classify_weather(temps[i], humidity[i])
        print(f"Day {i+1}: Temp = {temps[i]}°C, Humidity = {humidity[i]}%, Condition = {condition}")

# %% [markdown]
# **Output**

# %%
# Display report
analyze_daily_weather(temperatures, humidity_levels)

# Calculate and print averages
avg_temp = average_temperature(temperatures)
avg_humidity = average_humidity(humidity_levels)

print("\nAverage Temperature:", avg_temp, "°C")
print("Average Humidity:", avg_humidity, "%")
# Out:
# Weather Report for kerala:
#
# Day 1: Temp = 45°C, Humidity = 75%, Condition = Hot
# Day 2: Temp = 42°C, Humidity = 45%, Condition = Hot
# Day 3: Temp = 31°C, Humidity = 78%, Condition = Normal
# Day 4: Temp = 29°C, Humidity = 75%, Condition = Normal
# Day 5: Temp = 54°C, Humidity = 85%, Condition = Hot
# Day 6: Temp = 36°C, Humidity = 91%, Condition = Hot
# Day 7: Temp = 33°C, Humidity = 46%, Condition = Normal
#
# Average Temperature: 38.57142857142857 °C
# Average Humidity: 70.71428571428571 %
